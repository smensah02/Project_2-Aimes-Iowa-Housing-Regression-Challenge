# %% [markdown]
# ## Project 2 - Regression Challenge

# %% [markdown]
# ### Predict the price of homes at sale for the Aimes Iowa Housing dataset

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV, LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df_original = pd.read_csv('./Data/train (2).csv')
df_ktest_original = pd.read_csv('./Data/test (2).csv')

# %%
df = df_original.drop(['Id', 'PID'], axis=1)
df_ktest = df_ktest_original.drop(['Id', 'PID'], axis=1)

# %%
df.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           60        RL           NaN     13517   Pave   NaN       IR1
# 1           60        RL          43.0     11492   Pave   NaN       IR1
# 2           20        RL          68.0      7922   Pave   NaN       Reg
# 3           60        RL          73.0      9802   Pave   NaN       Reg
# 4           50        RL          82.0     14235   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config    ...     Screen Porch Pool Area Pool QC  \
# 0          Lvl    AllPub    CulDSac    ...                0         0     NaN
# 1          Lvl    AllPub    CulDSac    ...                0         0     NaN
# 2          Lvl    AllPub     Inside    ...                0         0     NaN
# 3          Lvl    AllPub     Inside    ...                0         0     NaN
# 4          Lvl    AllPub     Inside    ...                0         0     NaN
#
#   Fence Misc Feature Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice
# 0   NaN          NaN        0        3     2010        WD      130500
# 1   NaN          NaN        0        4     2009        WD      220000
# 2   NaN          NaN        0        1     2010        WD      109000
# 3   NaN          NaN        0        4     2010        WD      174000
# 4   NaN          NaN        0        3     2010        WD      138500
#
# [5 rows x 79 columns]

# %%
df_ktest.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0          190        RM          69.0      9142   Pave  Grvl       Reg
# 1           90        RL           NaN      9662   Pave   NaN       IR1
# 2           60        RL          58.0     17104   Pave   NaN       IR1
# 3           30        RM          60.0      8520   Pave   NaN       Reg
# 4           20        RL           NaN      9500   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config    ...     3Ssn Porch Screen Porch  \
# 0          Lvl    AllPub     Inside    ...              0            0
# 1          Lvl    AllPub     Inside    ...              0            0
# 2          Lvl    AllPub     Inside    ...              0            0
# 3          Lvl    AllPub     Inside    ...              0            0
# 4          Lvl    AllPub     Inside    ...              0          185
#
#   Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type
# 0         0     NaN   NaN          NaN         0        4     2006        WD
# 1         0     NaN   NaN          NaN         0        8     2006        WD
# 2         0     NaN   NaN          NaN         0        9     2006        New
# 3         0     NaN   NaN          NaN         0        7     2007        WD
# 4         0     NaN   NaN          NaN         0        7     2009        WD
#
# [5 rows x 78 columns]

# %%
df.shape
# Out:
# (2051, 79)

# %%
df.describe()
# Out:
#        MS SubClass  Lot Frontage       Lot Area  Overall Qual  Overall Cond  \
# count  2051.000000   1721.000000    2051.000000   2051.000000   2051.000000
# mean     57.008776     69.055200   10065.208191      6.112140      5.562165
# std      42.824223     23.260653    6742.488909      1.426271      1.104497
# min      20.000000     21.000000    1300.000000      1.000000      1.000000
# 25%      20.000000     58.000000    7500.000000      5.000000      5.000000
# 50%      50.000000     68.000000    9430.000000      6.000000      5.000000
# 75%      70.000000     80.000000   11513.500000      7.000000      6.000000
# max     190.000000    313.000000  159000.000000     10.000000      9.000000
#
#         Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# count  2051.000000     2051.000000   2029.000000   2050.000000   2050.000000
# mean   1971.708922     1984.190151     99.695909    442.300488     47.959024
# std      30.177889       21.036250    174.963129    461.204124    165.000901
# min    1872.000000     1950.000000      0.000000      0.000000      0.000000
# 25%    1953.500000     1964.500000      0.000000      0.000000      0.000000
# 50%    1974.000000     1993.000000      0.000000    368.000000      0.000000
# 75%    2001.000000     2004.000000    161.000000    733.750000      0.000000
# max    2010.000000     2010.000000   1600.000000   5644.000000   1474.000000
#
#            ...        Wood Deck SF  Open Porch SF  Enclosed Porch  \
# count      ...         2051.000000    2051.000000     2051.000000
# mean       ...           93.833740      47.556802       22.571916
# std        ...          128.549416      66.747241       59.845110
# min        ...            0.000000       0.000000        0.000000
# 25%        ...            0.000000       0.000000        0.000000
# 50%        ...            0.000000      27.000000        0.000000
# 75%        ...          168.000000      70.000000        0.000000
# max        ...         1424.000000     547.000000      432.000000
#
#         3Ssn Porch  Screen Porch    Pool Area      Misc Val      Mo Sold  \
# count  2051.000000   2051.000000  2051.000000   2051.000000  2051.000000
# mean      2.591419     16.511458     2.397855     51.574354     6.219893
# std      25.229615     57.374204    37.782570    573.393985     2.744736
# min       0.000000      0.000000     0.000000      0.000000     1.000000
# 25%       0.000000      0.000000     0.000000      0.000000     4.000000
# 50%       0.000000      0.000000     0.000000      0.000000     6.000000
# 75%       0.000000      0.000000     0.000000      0.000000     8.000000
# max     508.000000    490.000000   800.000000  17000.000000    12.000000
#
#            Yr Sold      SalePrice
# count  2051.000000    2051.000000
# mean   2007.775719  181469.701609
# std       1.312014   79258.659352
# min    2006.000000   12789.000000
# 25%    2007.000000  129825.000000
# 50%    2008.000000  162500.000000
# 75%    2009.000000  214000.000000
# max    2010.000000  611657.000000
#
# [8 rows x 37 columns]

# %%
#df.info()

# %%
#df.isnull().sum().sort_values(ascending=False)

# %%
# replace spaces in column names and convert all columns to lowercase:
df.columns = [x.lower().replace(' ','_') for x in df.columns]

# %%
df.head()
# Out:
#    ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 0           60        RL           NaN     13517   Pave   NaN       IR1
# 1           60        RL          43.0     11492   Pave   NaN       IR1
# 2           20        RL          68.0      7922   Pave   NaN       Reg
# 3           60        RL          73.0      9802   Pave   NaN       Reg
# 4           50        RL          82.0     14235   Pave   NaN       IR1
#
#   land_contour utilities lot_config    ...     screen_porch pool_area pool_qc  \
# 0          Lvl    AllPub    CulDSac    ...                0         0     NaN
# 1          Lvl    AllPub    CulDSac    ...                0         0     NaN
# 2          Lvl    AllPub     Inside    ...                0         0     NaN
# 3          Lvl    AllPub     Inside    ...                0         0     NaN
# 4          Lvl    AllPub     Inside    ...                0         0     NaN
#
#   fence misc_feature misc_val  mo_sold  yr_sold  sale_type  saleprice
# 0   NaN          NaN        0        3     2010        WD      130500
# 1   NaN          NaN        0        4     2009        WD      220000
# 2   NaN          NaN        0        1     2010        WD      109000
# 3   NaN          NaN        0        4     2010        WD      174000
# 4   NaN          NaN        0        3     2010        WD      138500
#
# [5 rows x 79 columns]

# %%
df_object = df.select_dtypes(include=['object'])

# %%
df_numbers = df.select_dtypes(exclude=['object'])

# %%
df_object.head()
# Out:
#   ms_zoning street alley lot_shape land_contour utilities lot_config  \
# 0        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 1        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 3        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 4        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
#
#   land_slope neighborhood condition_1    ...    fireplace_qu garage_type  \
# 0        Gtl       Sawyer        RRAe    ...             NaN      Attchd
# 1        Gtl      SawyerW        Norm    ...              TA      Attchd
# 2        Gtl        NAmes        Norm    ...             NaN      Detchd
# 3        Gtl       Timber        Norm    ...             NaN     BuiltIn
# 4        Gtl      SawyerW        Norm    ...             NaN      Detchd
#
#   garage_finish garage_qual garage_cond paved_drive pool_qc fence  \
# 0           RFn          TA          TA           Y     NaN   NaN
# 1           RFn          TA          TA           Y     NaN   NaN
# 2           Unf          TA          TA           Y     NaN   NaN
# 3           Fin          TA          TA           Y     NaN   NaN
# 4           Unf          TA          TA           N     NaN   NaN
#
#   misc_feature sale_type
# 0          NaN       WD
# 1          NaN       WD
# 2          NaN       WD
# 3          NaN       WD
# 4          NaN       WD
#
# [5 rows x 42 columns]

# %%
df_numbers.head()
# Out:
#    ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# 0           60           NaN     13517             6             8
# 1           60          43.0     11492             7             5
# 2           20          68.0      7922             5             7
# 3           60          73.0      9802             5             5
# 4           50          82.0     14235             6             8
#
#    year_built  year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  \
# 0        1976            2005         289.0         533.0           0.0
# 1        1996            1997         132.0         637.0           0.0
# 2        1953            2007           0.0         731.0           0.0
# 3        2006            2007           0.0           0.0           0.0
# 4        1900            1993           0.0           0.0           0.0
#
#      ...      wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 0    ...                 0             44               0           0
# 1    ...                 0             74               0           0
# 2    ...                 0             52               0           0
# 3    ...               100              0               0           0
# 4    ...                 0             59               0           0
#
#    screen_porch  pool_area  misc_val  mo_sold  yr_sold  saleprice
# 0             0          0         0        3     2010     130500
# 1             0          0         0        4     2009     220000
# 2             0          0         0        1     2010     109000
# 3             0          0         0        4     2010     174000
# 4             0          0         0        3     2010     138500
#
# [5 rows x 37 columns]

# %%
df_numbers.isnull().sum().sort_values(ascending=False)[:15]
# Out:
# lot_frontage      330
# garage_yr_blt     114
# mas_vnr_area       22
# bsmt_full_bath      2
# bsmt_half_bath      2
# garage_cars         1
# total_bsmt_sf       1
# bsmt_unf_sf         1
# bsmtfin_sf_2        1
# garage_area         1
# bsmtfin_sf_1        1
# gr_liv_area         0
# year_remod/add      0
# year_built          0
# overall_cond        0
# dtype: int64

# %%
df_numbers['lot_frontage'].fillna((0.0), inplace=True)
df_numbers['garage_yr_blt'].fillna((0.0), inplace=True)
df_numbers['mas_vnr_area'].fillna((0.0), inplace=True)
df_numbers['bsmt_half_bath'].fillna((0.0), inplace=True)
df_numbers['bsmt_full_bath'].fillna((0.0), inplace=True)
df_numbers['garage_cars'].fillna((0.0), inplace=True)
df_numbers['bsmtfin_sf_1'].fillna((0.0), inplace=True)
df_numbers['bsmtfin_sf_2'].fillna((0.0), inplace=True)
df_numbers['bsmt_unf_sf'].fillna((0.0), inplace=True)
df_numbers['total_bsmt_sf'].fillna((0.0), inplace=True)
df_numbers['garage_area'].fillna((0.0), inplace=True)
# Out:
# C:\Users\install\Anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_numbers.isnull().sum().sort_values(ascending=False)[:15]
# Out:
# saleprice          0
# bsmt_half_bath     0
# gr_liv_area        0
# low_qual_fin_sf    0
# 2nd_flr_sf         0
# 1st_flr_sf         0
# total_bsmt_sf      0
# bsmt_unf_sf        0
# bsmtfin_sf_2       0
# bsmtfin_sf_1       0
# mas_vnr_area       0
# year_remod/add     0
# year_built         0
# overall_cond       0
# overall_qual       0
# dtype: int64

# %%
df_numbers.head()
# Out:
#    ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# 0           60           0.0     13517             6             8
# 1           60          43.0     11492             7             5
# 2           20          68.0      7922             5             7
# 3           60          73.0      9802             5             5
# 4           50          82.0     14235             6             8
#
#    year_built  year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  \
# 0        1976            2005         289.0         533.0           0.0
# 1        1996            1997         132.0         637.0           0.0
# 2        1953            2007           0.0         731.0           0.0
# 3        2006            2007           0.0           0.0           0.0
# 4        1900            1993           0.0           0.0           0.0
#
#      ...      wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 0    ...                 0             44               0           0
# 1    ...                 0             74               0           0
# 2    ...                 0             52               0           0
# 3    ...               100              0               0           0
# 4    ...                 0             59               0           0
#
#    screen_porch  pool_area  misc_val  mo_sold  yr_sold  saleprice
# 0             0          0         0        3     2010     130500
# 1             0          0         0        4     2009     220000
# 2             0          0         0        1     2010     109000
# 3             0          0         0        4     2010     174000
# 4             0          0         0        3     2010     138500
#
# [5 rows x 37 columns]

# %%
features_list = [each for each in df_numbers.columns if each != 'saleprice']

# %%
X = df_numbers[features_list]
y = df_numbers['saleprice']

# %%
X.head()
# Out:
#    ms_subclass  lot_frontage  lot_area  overall_qual  overall_cond  \
# 0           60           0.0     13517             6             8
# 1           60          43.0     11492             7             5
# 2           20          68.0      7922             5             7
# 3           60          73.0      9802             5             5
# 4           50          82.0     14235             6             8
#
#    year_built  year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  \
# 0        1976            2005         289.0         533.0           0.0
# 1        1996            1997         132.0         637.0           0.0
# 2        1953            2007           0.0         731.0           0.0
# 3        2006            2007           0.0           0.0           0.0
# 4        1900            1993           0.0           0.0           0.0
#
#     ...     garage_area  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0   ...           475.0             0             44               0
# 1   ...           559.0             0             74               0
# 2   ...           246.0             0             52               0
# 3   ...           400.0           100              0               0
# 4   ...           484.0             0             59               0
#
#    3ssn_porch  screen_porch  pool_area  misc_val  mo_sold  yr_sold
# 0           0             0          0         0        3     2010
# 1           0             0          0         0        4     2009
# 2           0             0          0         0        1     2010
# 3           0             0          0         0        4     2010
# 4           0             0          0         0        3     2010
#
# [5 rows x 36 columns]

# %%
X.shape
# Out:
# (2051, 36)

# %%
#y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
df_numbers_corr = list(pd.concat([X_train, y_train],
                          axis=1).corr()['saleprice'].sort_values(ascending=False).index[1:38])

# %%
sns.heatmap(X_train[df_numbers_corr].corr(), vmin=-1, vmax=1);

# %%
X_train = X_train[df_numbers_corr]
X_test = X_test[df_numbers_corr]

# %%
# pipe = Pipeline([
#      ('pf', PolynomialFeatures()),
#     ('ss', StandardScaler()),
#     ('lr', LogisticRegression()),
# ])

# %%
# pipe.fit(X_train, y_train)

# %%
# params_grid ={
#     'pf__degree': [2],
#     'ss__with_mean': [True, False],
#     'ss__with_std': [True, False],
#     'lr__penalty': ['l1','l2'], # l2 is ridge which is default, l1 is lasso
#     'lr__solver': ['liblinear'],
#     'lr__C': np.logspace(-5, 0, 100)
# }

# %%
# gs = GridSearchCV(pipe, params_grid, n_jobs=-1, verbose=2, cv=3)

# %%
# gs.fit(X_train, y_train)

# %%
# pipe.fit(X_train, y_train)

# %%
# Logistic Regression model using only num variables and replacing nulls with mean of each variables
# print(pipe.score(X_train, y_train))
# print(pipe.score(X_test, y_test))
# 0.976592977893368
# 0.01949317738791423

# %%
# Logistic Regression model using only num variables and replacing nulls with 0 of each variables
# print(pipe.score(X_train, y_train))
# print(pipe.score(X_test, y_test))
# 0.9798439531859557
# 0.025341130604288498

# %%
#pipe.named_steps

# %%
#list(zip(pipe.named_steps['lr'].coef_, X_train.columns))

# %%
# pd.DataFrame({
#     'coefs': pipe.named_steps['pf'].get_feature_names(X_train.columns),
#     'vals': pipe.named_steps['lr'].coef_
# }).set_index('coefs').sort_values('vals', ascending=False)

# %%
# gs.best_score_
# gs.best_params_
# gs.score(X_train, y_train)
# gs.score(X_test, y_test)
# gs.best_estimator_.predict_proba(X_test)
# gs.best_estimator_.named_steps['lr'].coef_
# gs.predict(X_test)

# %%
# pipe = Pipeline([
#      ('pf', PolynomialFeatures()),
#     ('ss', StandardScaler()),
#     ('lr', LinearRegression()),
# ])

# %%
# pipe.fit(X_train, y_train)

# %%
# # linear regression model using only num variables and replacing nulls with mean of each variables
# print(pipe.score(X_train, y_train))
# print(pipe.score(X_test, y_test))
# 0.966166614677402
# -2.8546655569926435e+19

# %%
# # linear regression model using only num variables and replacing nulls with 0 for each variables
# print(pipe.score(X_train, y_train))
# print(pipe.score(X_test, y_test))
# 0.933090622538089
# -3.536508142059942e+22

# %%
X_train.shape
# Out:
# (1538, 36)

# %%
# LassoCv model using only num variables and replacing nulls with 0 for each variables
pipe = Pipeline([
    ('pf', PolynomialFeatures()),
    ('ss', StandardScaler()),
    ('lcv', LassoCV(n_alphas=500, max_iter=1000))
])

pipe.fit(X_train, y_train)

print(pipe.score(X_train, y_train))
print(pipe.score(X_test, y_test))
# Out:
# 0.9125709345616229
# 0.9084538877340118

# %%
pipe.named_steps['lcv'].alpha_
# Out:
# 1172.6651598990304

# %%
#list(zip(pipe.named_steps['lcv'].coef_, X_train.columns))

# %%
# pd.DataFrame({
#     'coefs': pipe.named_steps['pf'].get_feature_names(X_train.columns),
#     'vals': pipe.named_steps['lcv'].coef_
# }).set_index('coefs').sort_values('vals', ascending=False)

# %%
df_ktest.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0          190        RM          69.0      9142   Pave  Grvl       Reg
# 1           90        RL           NaN      9662   Pave   NaN       IR1
# 2           60        RL          58.0     17104   Pave   NaN       IR1
# 3           30        RM          60.0      8520   Pave   NaN       Reg
# 4           20        RL           NaN      9500   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config    ...     3Ssn Porch Screen Porch  \
# 0          Lvl    AllPub     Inside    ...              0            0
# 1          Lvl    AllPub     Inside    ...              0            0
# 2          Lvl    AllPub     Inside    ...              0            0
# 3          Lvl    AllPub     Inside    ...              0            0
# 4          Lvl    AllPub     Inside    ...              0          185
#
#   Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type
# 0         0     NaN   NaN          NaN         0        4     2006        WD
# 1         0     NaN   NaN          NaN         0        8     2006        WD
# 2         0     NaN   NaN          NaN         0        9     2006        New
# 3         0     NaN   NaN          NaN         0        7     2007        WD
# 4         0     NaN   NaN          NaN         0        7     2009        WD
#
# [5 rows x 78 columns]

# %%
# replace spaces in column names and convert all columns to lowercase:
df_ktest.columns = [x.lower().replace(' ','_') for x in df_ktest.columns]

# %%
df_ktest.head()
# Out:
#    ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 0          190        RM          69.0      9142   Pave  Grvl       Reg
# 1           90        RL           NaN      9662   Pave   NaN       IR1
# 2           60        RL          58.0     17104   Pave   NaN       IR1
# 3           30        RM          60.0      8520   Pave   NaN       Reg
# 4           20        RL           NaN      9500   Pave   NaN       IR1
#
#   land_contour utilities lot_config    ...     3ssn_porch screen_porch  \
# 0          Lvl    AllPub     Inside    ...              0            0
# 1          Lvl    AllPub     Inside    ...              0            0
# 2          Lvl    AllPub     Inside    ...              0            0
# 3          Lvl    AllPub     Inside    ...              0            0
# 4          Lvl    AllPub     Inside    ...              0          185
#
#   pool_area pool_qc fence misc_feature  misc_val  mo_sold  yr_sold  sale_type
# 0         0     NaN   NaN          NaN         0        4     2006        WD
# 1         0     NaN   NaN          NaN         0        8     2006        WD
# 2         0     NaN   NaN          NaN         0        9     2006        New
# 3         0     NaN   NaN          NaN         0        7     2007        WD
# 4         0     NaN   NaN          NaN         0        7     2009        WD
#
# [5 rows x 78 columns]

# %%
df_ktest_numbers = df_ktest.select_dtypes(exclude=['object'])

# %%
df_ktest_numbers.shape
# Out:
# (879, 36)

# %%
df_ktest_numbers.isnull().sum().sort_values(ascending=False)[:15]
# Out:
# lot_frontage       160
# garage_yr_blt       45
# mas_vnr_area         1
# yr_sold              0
# bsmtfin_sf_2         0
# low_qual_fin_sf      0
# 2nd_flr_sf           0
# 1st_flr_sf           0
# total_bsmt_sf        0
# bsmt_unf_sf          0
# bsmtfin_sf_1         0
# bsmt_full_bath       0
# year_remod/add       0
# year_built           0
# overall_cond         0
# dtype: int64

# %%
df_ktest_numbers['lot_frontage'].fillna((0.0), inplace=True)
df_ktest_numbers['garage_yr_blt'].fillna((0.0), inplace=True)
df_ktest_numbers['mas_vnr_area'].fillna((0.0), inplace=True)
# Out:
# C:\Users\install\Anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df_ktest_numbers.isnull().sum().sort_values(ascending=False)[:15]
# Out:
# yr_sold            0
# mo_sold            0
# gr_liv_area        0
# low_qual_fin_sf    0
# 2nd_flr_sf         0
# 1st_flr_sf         0
# total_bsmt_sf      0
# bsmt_unf_sf        0
# bsmtfin_sf_2       0
# bsmtfin_sf_1       0
# mas_vnr_area       0
# year_remod/add     0
# year_built         0
# overall_cond       0
# overall_qual       0
# dtype: int64

# %%
X_train.shape
# Out:
# (1538, 36)

# %%
df_ktest_numbers.shape
# Out:
# (879, 36)

# %%
# probably need to drop 'id' from both

# %%
X_train[sorted(X_train.columns)].head()
# Out:
#       1st_flr_sf  2nd_flr_sf  3ssn_porch  bedroom_abvgr  bsmt_full_bath  \
# 532         1587           0           0              3             0.0
# 415         1262        1005           0              3             1.0
# 273          864           0           0              3             1.0
# 1460        1306         954           0              3             1.0
# 250         1251        1250           0              4             0.0
#
#       bsmt_half_bath  bsmt_unf_sf  bsmtfin_sf_1  bsmtfin_sf_2  enclosed_porch  \
# 532              0.0        749.0         838.0           0.0               0
# 415              0.0        717.0         288.0           0.0               0
# 273              0.0        317.0         398.0         149.0               0
# 1460             0.0        105.0        1201.0           0.0               0
# 250              0.0       1242.0           0.0           0.0               0
#
#        ...     overall_cond  overall_qual  pool_area  screen_porch  \
# 532    ...                6             6          0             0
# 415    ...                8             7          0             0
# 273    ...                8             5          0             0
# 1460   ...                5             7          0             0
# 250    ...                7             8          0             0
#
#       total_bsmt_sf  totrms_abvgrd  wood_deck_sf  year_built  year_remod/add  \
# 532          1587.0              7             0        1971            1971
# 415          1005.0              7           521        1937            1980
# 273           864.0              5           194        1950            2002
# 1460         1306.0              7           296        1996            1997
# 250          1242.0              9           192        1995            1995
#
#       yr_sold
# 532      2007
# 415      2007
# 273      2007
# 1460     2010
# 250      2008
#
# [5 rows x 36 columns]

# %%
df_ktest_numbers[sorted(df_ktest_numbers)].head()
# Out:
#    1st_flr_sf  2nd_flr_sf  3ssn_porch  bedroom_abvgr  bsmt_full_bath  \
# 0         908        1020           0              4             0.0
# 1        1967           0           0              6             0.0
# 2         664         832           0              3             1.0
# 3         968           0           0              2             0.0
# 4        1394           0           0              3             1.0
#
#    bsmt_half_bath  bsmt_unf_sf  bsmtfin_sf_1  bsmtfin_sf_2  enclosed_porch  \
# 0             0.0       1020.0           0.0           0.0             112
# 1             0.0       1967.0           0.0           0.0               0
# 2             0.0        100.0         554.0           0.0               0
# 3             0.0        968.0           0.0           0.0             184
# 4             0.0        785.0         609.0           0.0               0
#
#     ...     overall_cond  overall_qual  pool_area  screen_porch  \
# 0   ...                8             6          0             0
# 1   ...                4             5          0             0
# 2   ...                5             7          0             0
# 3   ...                6             5          0             0
# 4   ...                5             6          0           185
#
#    total_bsmt_sf  totrms_abvgrd  wood_deck_sf  year_built  year_remod/add  \
# 0         1020.0              9             0        1910            1950
# 1         1967.0             10           170        1977            1977
# 2          654.0              7           100        2006            2006
# 3          968.0              5             0        1923            2006
# 4         1394.0              6             0        1963            1963
#
#    yr_sold
# 0     2006
# 1     2006
# 2     2006
# 3     2007
# 4     2009
#
# [5 rows x 36 columns]

# %%
set(df_ktest_numbers.columns) ^ set(X_train.columns)
# Out:
# set()

# %%
#set_df = set(X_train.columns) & set(df_ktest_numbers.columns)

# %%
preds = pipe.predict(df_ktest_numbers)

# %%
ids = df_ktest_original['Id']

preds_df = pd.DataFrame({
    'Id': ids,
    'saleprice': preds
})

# %%
import datetime

now = str(datetime.datetime.now())

f'predictions_{now}'

now1 = str(datetime.datetime.now())
preds_df.to_csv('kaggle_Preds_{now1}', index=False)

# %%
# pd.read_csv('kaggle_Preds_{now1}')
